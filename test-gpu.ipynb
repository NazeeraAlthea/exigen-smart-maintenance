# %%
import torch

print("Apakah CUDA (GPU) tersedia?: ", torch.cuda.is_available())
if torch.cuda.is_available():
    print("Nama GPU milikmu:", torch.cuda.get_device_name(0))
else:
    print("Masih pakai CPU, instalasi CUDA gagal.")
# Out:
# Apakah CUDA (GPU) tersedia?:  True
# Nama GPU milikmu: NVIDIA GeForce RTX 3060 Laptop GPU
